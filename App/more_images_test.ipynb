# %%
import cv2
import tensorflow as tf
from PIL import Image
import numpy as np  

Categories = ["Closed","Left","Right"]
#Categories = ["Closed","Left","Open","Right"]

def prepare(filepath):
    img_size = 224
    img_array = cv2.imread(filepath)
    new_array = cv2.resize(img_array,(img_size,img_size),3)
    return new_array.reshape(-1,img_size,img_size,3)

model = tf.keras.models.load_model(r"C:\MyProject\397199_397209\Models\ThreeClassModel6_model.h5")

rightSayac = 0
leftSayac = 0
closedSayac = 0
#openSayac = 0


for i in range(1,93):
    #img = 'C:\MyProject\Proje\Version2\Data\CroppedDataSet\Train\Right\Right ('+str(i)+').jpg'
    prediction = model.predict([prepare(r'C:\MyProject\397199_397209\Data\ThreeClassDataBase\Test\Right\Right ('+str(i)+').jpg')])
    #print(prediction)
    indis = np.argmax(prediction[0])
    """max = -1
    indis = -1
    for x in range(3):
        if prediction[0][x]>max:
            indis = x
            max = prediction[0][x]"""
    
    print("TEST SONUCU "+str(i)+" :"+Categories[indis])

    if Categories[indis] == "Closed":
        closedSayac+=1
    elif Categories[indis] == "Left":
        leftSayac+=1
    #elif Categories[indis] == "Open": openSayac+=1
    else:
        rightSayac+=1
    
print("Closed Sonucu: ",closedSayac)
print("Left Sonucu: ",leftSayac)
#print("Open Sonucu: ",openSayac)
print("Right Sonucu: ",rightSayac)
# Out:
# TEST SONUCU 1 :Right
# TEST SONUCU 2 :Right
# TEST SONUCU 3 :Right
# TEST SONUCU 4 :Right
# TEST SONUCU 5 :Right
# TEST SONUCU 6 :Right
# TEST SONUCU 7 :Right
# TEST SONUCU 8 :Right
# TEST SONUCU 9 :Right
# TEST SONUCU 10 :Right
# TEST SONUCU 11 :Right
# TEST SONUCU 12 :Right
# TEST SONUCU 13 :Right
# TEST SONUCU 14 :Right
# TEST SONUCU 15 :Right
# TEST SONUCU 16 :Right
# TEST SONUCU 17 :Right
# TEST SONUCU 18 :Right
# TEST SONUCU 19 :Right
# TEST SONUCU 20 :Right
# TEST SONUCU 21 :Right
# TEST SONUCU 22 :Right
# TEST SONUCU 23 :Right
# TEST SONUCU 24 :Right
# TEST SONUCU 25 :Right
# TEST SONUCU 26 :Right
# TEST SONUCU 27 :Right
# TEST SONUCU 28 :Right
# TEST SONUCU 29 :Right
# TEST SONUCU 30 :Right
# TEST SONUCU 31 :Right
# TEST SONUCU 32 :Right
# TEST SONUCU 33 :Right
# TEST SONUCU 34 :Right
# TEST SONUCU 35 :Right
# TEST SONUCU 36 :Right
# TEST SONUCU 37 :Right
# TEST SONUCU 38 :Right
# TEST SONUCU 39 :Right
# TEST SONUCU 40 :Right
# TEST SONUCU 41 :Right
# TEST SONUCU 42 :Right
# TEST SONUCU 43 :Right
# TEST SONUCU 44 :Right
# TEST SONUCU 45 :Right
# TEST SONUCU 46 :Right
# TEST SONUCU 47 :Right
# TEST SONUCU 48 :Right
# TEST SONUCU 49 :Right
# TEST SONUCU 50 :Right
# TEST SONUCU 51 :Right
# TEST SONUCU 52 :Right
# TEST SONUCU 53 :Right
# TEST SONUCU 54 :Right
# TEST SONUCU 55 :Right
# TEST SONUCU 56 :Right
# TEST SONUCU 57 :Right
# TEST SONUCU 58 :Right
# TEST SONUCU 59 :Right
# TEST SONUCU 60 :Right
# TEST SONUCU 61 :Right
# TEST SONUCU 62 :Right
# TEST SONUCU 63 :Right
# TEST SONUCU 64 :Right
# TEST SONUCU 65 :Right
# TEST SONUCU 66 :Right
# TEST SONUCU 67 :Right
# TEST SONUCU 68 :Right
# TEST SONUCU 69 :Right
# TEST SONUCU 70 :Right
# TEST SONUCU 71 :Right
# TEST SONUCU 72 :Right
# TEST SONUCU 73 :Right
# TEST SONUCU 74 :Closed
# TEST SONUCU 75 :Right
# TEST SONUCU 76 :Right
# TEST SONUCU 77 :Right
# TEST SONUCU 78 :Right
# TEST SONUCU 79 :Right
# TEST SONUCU 80 :Right
# TEST SONUCU 81 :Right
# TEST SONUCU 82 :Right
# TEST SONUCU 83 :Right
# TEST SONUCU 84 :Right
# TEST SONUCU 85 :Right
# TEST SONUCU 86 :Right
# TEST SONUCU 87 :Right
# TEST SONUCU 88 :Right
# TEST SONUCU 89 :Right
# TEST SONUCU 90 :Right
# TEST SONUCU 91 :Right
# TEST SONUCU 92 :Right
# Closed Sonucu:  1
# Left Sonucu:  0
# Right Sonucu:  91
